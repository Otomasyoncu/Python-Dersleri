# %%
import sys
from PyQt5 import QtWidgets, QtGui
from PyQt5.QtCore import *
uygulama = QtWidgets.QApplication(sys.argv)

pencere = QtWidgets.QWidget()
pencere.setWindowTitle("Hesap Makinesi")
pencere.setGeometry(400, 100, 400, 400)

ekran = QtWidgets.QLineEdit(pencere)
ekran.setText("0")
ekran.move(10,10)
ekran.setFixedSize(155, 30)
ekran.setEnabled(False)
ekran.setFont(QtGui.QFont("Times", 14, QtGui.QFont.Bold))
ekran.setAlignment(Qt.AlignRight)

def btn01_click():
    if ekran.text() == "0":
        ekran.setText("1")
    else:
        ekran.setText(ekran.text() + "1")

btn01 = QtWidgets.QPushButton(pencere)
btn01.setText("1")
btn01.move(10, 125)
btn01.setFixedSize(35, 35)
btn01.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn01.clicked.connect(btn01_click)

def btn02_click():
    if ekran.text() == "0":
        ekran.setText("2")
    else:
        ekran.setText(ekran.text() + "2")

btn02 = QtWidgets.QPushButton(pencere)
btn02.setText("2")
btn02.move(50, 125)
btn02.setFixedSize(35, 35)
btn02.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn02.clicked.connect(btn02_click)

def btn03_click():
    if ekran.text() == "0":
        ekran.setText("3")
    else:
        ekran.setText(ekran.text() + "3")

btn03 = QtWidgets.QPushButton(pencere)
btn03.setText("3")
btn03.move(90, 125)
btn03.setFixedSize(35, 35)
btn03.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn03.clicked.connect(btn03_click)

def btn04_click():
    if ekran.text() == "0":
        ekran.setText("4")
    else:
        ekran.setText(ekran.text() + "4")

btn04 = QtWidgets.QPushButton(pencere)
btn04.setText("4")
btn04.move(10, 85)
btn04.setFixedSize(35, 35)
btn04.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn04.clicked.connect(btn04_click)

def btn05_click():
    if ekran.text() == "0":
        ekran.setText("5")
    else:
        ekran.setText(ekran.text() + "5")

btn05 = QtWidgets.QPushButton(pencere)
btn05.setText("5")
btn05.move(50, 85)
btn05.setFixedSize(35, 35)
btn05.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn05.clicked.connect(btn05_click)

def btn06_click():
    if ekran.text() == "0":
        ekran.setText("6")
    else:
        ekran.setText(ekran.text() + "6")

btn06 = QtWidgets.QPushButton(pencere)
btn06.setText("6")
btn06.move(90, 85)
btn06.setFixedSize(35, 35)
btn06.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn06.clicked.connect(btn06_click)

def btn07_click():
    if ekran.text() == "0":
        ekran.setText("7")
    else:
        ekran.setText(ekran.text() + "7")

btn07 = QtWidgets.QPushButton(pencere)
btn07.setText("7")
btn07.move(10, 45)
btn07.setFixedSize(35, 35)
btn07.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn07.clicked.connect(btn07_click)

def btn08_click():
    if ekran.text() == "0":
        ekran.setText("8")
    else:
        ekran.setText(ekran.text() + "8")

btn08 = QtWidgets.QPushButton(pencere)
btn08.setText("8")
btn08.move(50, 45)
btn08.setFixedSize(35, 35)
btn08.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn08.clicked.connect(btn08_click)

def btn09_click():
    if ekran.text() == "0":
        ekran.setText("9")
    else:
        ekran.setText(ekran.text() + "9")

btn09 = QtWidgets.QPushButton(pencere)
btn09.setText("9")
btn09.move(90, 45)
btn09.setFixedSize(35, 35)
btn09.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btn09.clicked.connect(btn09_click)

a=0
b=0
islem="yok"
def btneksi_click():
    if ekran.text() != "0":
        global islem
        islem="-"
        global a
        a = int(ekran.text())
        ekran.setText("0")

btneksi = QtWidgets.QPushButton(pencere)
btneksi.setText("-")
btneksi.move(130, 45)
btneksi.setFixedSize(35, 35)
btneksi.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btneksi.clicked.connect(btneksi_click)

def btnarti_click():
    if ekran.text() != "0":
        global islem
        islem = "+"
        global a
        a = int(ekran.text())
        ekran.setText("0")

btnarti = QtWidgets.QPushButton(pencere)
btnarti.setText("+")
btnarti.move(130, 85)
btnarti.setFixedSize(35, 35)
btnarti.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btnarti.clicked.connect(btnarti_click)

def btntop_click():
    global b
    b = int(ekran.text())
    if islem=="+":
        c = a + b
        ekran.setText(str(c))
    elif islem =="-":
        c = a - b
        ekran.setText(str(c))

btntop = QtWidgets.QPushButton(pencere)
btntop.setText("=")
btntop.move(130, 125)
btntop.setFixedSize(35, 35)
btntop.setFont(QtGui.QFont("Times", 12, QtGui.QFont.Bold))
btntop.setStyleSheet("background-color: red")
btntop.clicked.connect(btntop_click)



pencere.show()
sys.exit(uygulama.exec_())
