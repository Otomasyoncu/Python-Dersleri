# %%
import sys , pyodbc
from PyQt5 import QtWidgets, QtGui
from PyQt5.QtCore import *
uygulama = QtWidgets.QApplication(sys.argv)

pencere01 = QtWidgets.QWidget()
pencere01.setWindowTitle("Kayıt Ol")
pencere01.setGeometry(400, 50, 500, 500)
pencere01.setWindowIcon(QtGui.QIcon("logo.ico"))

etiket01 = QtWidgets.QLabel(pencere01)
etiket01.setText("Adınız       :")
etiket01.move(20, 23)
etiket01.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket02 = QtWidgets.QLabel(pencere01)
etiket02.setText("Soyadiniz :")
etiket02.move(20, 53)
etiket02.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket03 = QtWidgets.QLabel(pencere01)
etiket03.setText("Sinifiniz    :")
etiket03.move(20, 83)
etiket03.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket04 = QtWidgets.QLabel(pencere01)
etiket04.setText("Adresiniz  :")
etiket04.move(20, 113)
etiket04.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket05 = QtWidgets.QLabel(pencere01)
etiket05.setText("İliniz         :")
etiket05.move(20, 143)
etiket05.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket06 = QtWidgets.QLabel(pencere01)
etiket06.setText("İlceniz      :")
etiket06.move(20, 173)
etiket06.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

grupbox01 = QtWidgets.QGroupBox(pencere01)
grupbox01.setTitle("")
grupbox01.setGeometry(10, 200, 365, 140)

etiket07 = QtWidgets.QLabel(grupbox01)
etiket07.setText("Dersler     :")
etiket07.move(10, 10)
etiket07.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

textbox01 = QtWidgets.QLineEdit(pencere01)
textbox01.setText("")
textbox01.setGeometry(100,20,275,25)
textbox01.setEnabled(True)
textbox01.setFont(QtGui.QFont("Times", 10))
textbox01.setAlignment(Qt.AlignLeft)

textbox02 = QtWidgets.QLineEdit(pencere01)
textbox02.setText("")
textbox02.setGeometry(100,50,275,25)
textbox02.setEnabled(True)
textbox02.setFont(QtGui.QFont("Times", 10))
textbox02.setAlignment(Qt.AlignLeft)

radio01 = QtWidgets.QRadioButton(pencere01)
radio01.setChecked(False)
radio01.setText("9.Sınıf")
radio01.move(100,85)

radio02 = QtWidgets.QRadioButton(pencere01)
radio02.setChecked(False)
radio02.setText("10.Sınıf")
radio02.move(170,85)

radio03 = QtWidgets.QRadioButton(pencere01)
radio03.setChecked(False)
radio03.setText("11.Sınıf")
radio03.move(240,85)

radio04 = QtWidgets.QRadioButton(pencere01)
radio04.setChecked(False)
radio04.setText("12.Sınıf")
radio04.move(310,85)

textbox03 = QtWidgets.QLineEdit(pencere01)
textbox03.setText("")
textbox03.setGeometry(100,110,275,25)
textbox03.setEnabled(True)
textbox03.setFont(QtGui.QFont("Times", 10))
textbox03.setAlignment(Qt.AlignLeft)

def serkan01():
    if combobox01.currentText() == "Ankara":
        combobox02.clear()
        combobox02.addItem("Çankaya")
        combobox02.addItem("Keçiören")
        combobox02.addItem("Polatlı")
    elif combobox01.currentText() == "İstanbul":
        combobox02.clear()
        combobox02.addItem("Kartal")
        combobox02.addItem("Pendik")
        combobox02.addItem("Tuzla")
    elif combobox01.currentText() == "İzmir":
        combobox02.clear()
        combobox02.addItem("Bornova")
        combobox02.addItem("Karşıyaka")
        combobox02.addItem("Menemen")
    elif combobox01.currentText() == "Kocaeli":
        combobox02.clear()
        combobox02.addItem("Gebze")
        combobox02.addItem("Gölcük")
        combobox02.addItem("Derince")
    elif combobox01.currentText() == "Sakarya":
        combobox02.clear()
        combobox02.addItem("Adapazarı")
        combobox02.addItem("Hendek")
        combobox02.addItem("Karasu")

combobox01 = QtWidgets.QComboBox(pencere01)
combobox01.setGeometry(100, 140, 275, 25)
combobox01.addItem("Ankara")
combobox01.addItem("İstanbul")
combobox01.addItem("İzmir")
combobox01.addItem("Kocaeli")
combobox01.addItem("Sakarya")
combobox01.currentTextChanged.connect(serkan01)

combobox02 = QtWidgets.QComboBox(pencere01)
combobox02.setGeometry(100, 170, 275, 25)
combobox02.addItem("Çankaya")
combobox02.addItem("Keçiören")
combobox02.addItem("Polatlı")

checkbox01 = QtWidgets.QCheckBox(grupbox01)
checkbox01.setChecked(False)
checkbox01.setText("Bilgisayarlı Kontrol")
checkbox01.move(90,10)

checkbox02 = QtWidgets.QCheckBox(grupbox01)
checkbox02.setChecked(False)
checkbox02.setText("Ardışık Kontrol")
checkbox02.move(90,35)

checkbox03 = QtWidgets.QCheckBox(grupbox01)
checkbox03.setChecked(False)
checkbox03.setText("Temel Bilgisayar Ağları")
checkbox03.move(90,60)

checkbox04 = QtWidgets.QCheckBox(grupbox01)
checkbox04.setChecked(False)
checkbox04.setText("Sinyal İşleme ve Algılayıcılar")
checkbox04.move(90,85)

checkbox05 = QtWidgets.QCheckBox(grupbox01)
checkbox05.setChecked(False)
checkbox05.setText("Otomatik Üretim")
checkbox05.move(90,110)

pencere02 = QtWidgets.QWidget()
pencere02.setWindowTitle("Kayıt İşlemi Tamamlandı")
pencere02.setGeometry(450, 100, 400, 400)
pencere02.setWindowIcon(QtGui.QIcon("logo.ico"))

etiket11 = QtWidgets.QLabel(pencere02)
etiket11.setText("Adınız       :")
etiket11.move(20, 23)
etiket11.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket12 = QtWidgets.QLabel(pencere02)
etiket12.setText("Soyadiniz :")
etiket12.move(20, 53)
etiket12.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket13 = QtWidgets.QLabel(pencere02)
etiket13.setText("Sinifiniz    :")
etiket13.move(20, 83)
etiket13.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket14 = QtWidgets.QLabel(pencere02)
etiket14.setText("Adresiniz  :                                             ")
etiket14.move(20, 113)
etiket14.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket15 = QtWidgets.QLabel(pencere02)
etiket15.setText("İliniz         :")
etiket15.move(20, 143)
etiket15.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket16 = QtWidgets.QLabel(pencere02)
etiket16.setText("İlceniz      :")
etiket16.move(20, 173)
etiket16.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket17 = QtWidgets.QLabel(pencere02)
etiket17.setText("Dersler   :")
etiket17.move(20, 203)
etiket17.setFont(QtGui.QFont("Arial", 10, QtGui.QFont.Bold))

etiket18 = QtWidgets.QLabel(pencere02)
etiket18.setText("Bilgisayarlı Kontrol                            ")
etiket18.move(90, 205)

etiket19 = QtWidgets.QLabel(pencere02)
etiket19.setText("Ardışık Kontrol                                 ")
etiket19.move(90, 225)

etiket20 = QtWidgets.QLabel(pencere02)
etiket20.setText("Temel Bilgisayar Ağları                         ")
etiket20.move(90, 245)

etiket21 = QtWidgets.QLabel(pencere02)
etiket21.setText("Sinyal İşleme ve Algılayıcılar                  ")
etiket21.move(90, 265)

etiket22 = QtWidgets.QLabel(pencere02)
etiket22.setText("Otomatik Üretim                                 ")
etiket22.move(90, 285)

def serkan():
    pencere02.show()
    etiket11.setText(textbox01.text())
    etiket12.setText(textbox02.text())
    sinif = " "
    if radio01.isChecked() == True:
        sinif = "9.Sinif"
    elif radio02.isChecked() == True:
        sinif = "10.Sinif"
    elif radio03.isChecked() == True:
        sinif = "11.Sinif"
    elif radio04.isChecked() == True:
        sinif = "12.Sinif"
    etiket13.setText(sinif)
    etiket14.setText(textbox03.text())
    etiket15.setText(combobox01.currentText())
    etiket16.setText(combobox02.currentText())
    if checkbox01.isChecked() == True:
        etiket18.setFont(QtGui.QFont("Calibri", 10, QtGui.QFont.Bold))
    if checkbox02.isChecked() == True:
        etiket19.setFont(QtGui.QFont("Calibri", 10, QtGui.QFont.Bold))
    if checkbox03.isChecked() == True:
        etiket20.setFont(QtGui.QFont("Calibri", 10, QtGui.QFont.Bold))
    if checkbox04.isChecked() == True:
        etiket21.setFont(QtGui.QFont("Calibri", 10, QtGui.QFont.Bold))
    if checkbox05.isChecked() == True:
        etiket22.setFont(QtGui.QFont("Calibri", 10, QtGui.QFont.Bold))

buton01 = QtWidgets.QPushButton(pencere01)
buton01.setText("Tamam")
buton01.move(100,350)
buton01.setFixedSize(275, 40)
buton01.setFont(QtGui.QFont("Calibri", 10, QtGui.QFont.Bold))
buton01.clicked.connect(serkan)

pencere01.show()
sys.exit(uygulama.exec_())
